# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..','..')))

# %%
from feature_engineering import FeatureExtraction
import pandas as pd

# %%
file_path = "../../data/Expenditure-of-local-bodies.xlsx"
if not os.path.exists(file_path):
    print("Dataset not found!")
else:
    print("Good to go!")
# Out:
# Good to go!

# %%
feature_extraction = FeatureExtraction(fname=file_path, province_name="Bagmati Province")
budget, expense = feature_extraction.extract_individual()
budget.head()
# Out:
# Original data extracted successfully☺️
# DataFrame Renamed successfully☺️
# ALL THE OPERSTIONS WERE SUCCESSFUL😊
#       SN                       Local Body  Recurrent    Capital Financial  \
# 277  274                Jiri Municipality    32.1781  21.796821       0.0
# 278  275          Bhimeshwor Municipality  40.456662  53.925065      0.15
# 279  276    Kalinchwok Rural Municipality  43.495598   30.00791       0.0
# 280  277  Gaurisahnkar Rural Municipality   29.82713    20.8173       0.0
# 281  278     Tamakoshi Rural Municipality  44.341532  26.595364       0.0
#
#          Total Cash Balance
# 277  53.974921     5.259159
# 278  94.531727     6.743792
# 279  73.503508     8.158327
# 280   50.64443     4.510428
# 281  70.936896    17.064383

# %%
df = feature_extraction.open_file()
df = feature_extraction.rename_label(dataframe=df)

# %%
df.head(10)
# Out:
#    SN                                Local Body  Recurrent    Capital  \
# 0   1                    Phungling Municipality  38.550184  26.144191
# 1   2        Aathrai Tribeni Rural Municipality   26.79269  22.705015
# 2   3          Phaktanglung  Rural Municipality  30.862931  15.232376
# 3   4            Mikwakhola  Rural Municipality  20.730677  11.014579
# 4   5             Meringdeng Rural Municipality  26.518959  16.155819
# 5   6             Mauwakhola Rural Municipality   21.46895    14.5531
# 6   7  Pathibhara Yangwarak  Rural Municipality  27.369047  21.029567
# 7   8              Sidingwa  Rural Municipality   30.86315  12.018302
# 8   9            Sirijangha  Rural Municipality  34.966189    16.8545
# 9  10                       Phidim Municipality  80.195151     16.536
#
#   Financial      Total  Recurrent    Capital Financial      Total Cash Balance
# 0       0.0  64.694376  34.104109  24.514032       0.0   58.61814     7.666711
# ...

# %%
df.columns
# Out:
# Index(['SN', 'Local Body', 'Recurrent', 'Capital', 'Financial', 'Total',
#        'Recurrent', 'Capital', 'Financial', 'Total', 'Cash Balance'],
#       dtype='object')

# %%
df['SN'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: SN, dtype: object

# %%
df = feature_extraction.extract_expenditure_frame(df)
df.head()
# Out:
#   SN                          Local Body  Recurrent    Capital Financial  \
# 0  1              Phungling Municipality  34.104109  24.514032       0.0
# 1  2  Aathrai Tribeni Rural Municipality   21.72991  13.335082       0.0
# 2  3    Phaktanglung  Rural Municipality  24.071506  12.591538       0.0
# 3  4      Mikwakhola  Rural Municipality  16.349711   8.581009       0.0
# 4  5       Meringdeng Rural Municipality  23.587589  15.188281       0.0
#
#        Total Cash Balance
# 0   58.61814     7.666711
# 1  35.064991    12.857007
# 2  36.663044      7.17987
# 3   24.93072     6.718961
# 4  38.775871     2.881517

# %%
df_filtered = df[df["Local Body"].str.contains(r'(?:Sub-Metropolitan|Metropolitan)$', case=False, na=False)]
df_filtered.head()
# Out:
#       SN                     Local Body   Recurrent    Capital Financial  \
# 108  109        Biratnagar Metropolitan  106.329656  86.189002   4.30181
# 125  126       Itahari Sub-Metropolitan   83.120802  51.578389       0.0
# 126  127        Dharan Sub-Metropolitan   81.431079   49.05564    2.9477
# 174  173  Janakpurdham Sub-Metropolitan   85.549529  40.428753       0.0
# 245  244       Kalaiya Sub-Metropolitan   65.561599  55.608887       0.0
#
#           Total Cash Balance
# 108  196.820467     46.12698
# 125  134.699191    48.036981
# 126   133.43442    29.887517
# 174  125.978283    44.862408
# 245  121.170486     26.22197

# %%
df_filtered.shape
# Out:
# (17, 7)

# %%
def filter_list(dataframe: pd.DataFrame):
    df = dataframe[dataframe["Local Body"].str.contains(r'?:Sub-Metropolitan|Metropolitan)$', case=False, na=False)]
    return df

# %% [markdown]
# ### Testing implementation

# %%
from feature_engineering import FeatureExtractionUrban

# %%
final_df = FeatureExtractionUrban(df=budget).extract_urban_features()
final_df.head()
# Out:
#       SN                Local Body   Recurrent     Capital Financial  \
# 358  355    Bharatpur Metropolitan  197.692678  292.229399       0.0
# 365  362  Hetauda Sub-Metropolitan  119.985973  133.746327       0.6
# 379  376     Lalitpur Metropolitan  142.927227  273.752645       0.0
# 385  382    Kathmandu Metropolitan    546.5301    972.5085   37.1128
#
#           Total Cash Balance
# 358  489.922077   163.427313
# 365    254.3323   105.282164
# 379  416.679872   181.757992
# 385   1556.1514   983.660309

# %%
final_df.size
# Out:
# 28

# %%
final_df.shape
# Out:
# (4, 7)

# %%
final_df = FeatureExtractionUrban(df=df).extract_urban_features()
final_df.head()
# Out:
#       SN                     Local Body   Recurrent    Capital Financial  \
# 108  109        Biratnagar Metropolitan  106.329656  86.189002   4.30181
# 125  126       Itahari Sub-Metropolitan   83.120802  51.578389       0.0
# 126  127        Dharan Sub-Metropolitan   81.431079   49.05564    2.9477
# 174  173  Janakpurdham Sub-Metropolitan   85.549529  40.428753       0.0
# 245  244       Kalaiya Sub-Metropolitan   65.561599  55.608887       0.0
#
#           Total Cash Balance
# 108  196.820467     46.12698
# 125  134.699191    48.036981
# 126   133.43442    29.887517
# 174  125.978283    44.862408
# 245  121.170486     26.22197

# %%
final_df.shape
# Out:
# (17, 7)

# %% [markdown]
# ### working fine
